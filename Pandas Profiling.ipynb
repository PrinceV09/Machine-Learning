# %%
import pandas as pd

# %%
df = pd.read_csv('tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (2.10.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\princ\anaconda3\lib\site-packages (from pandas-profiling) (2.1.3)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [19 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#       exec(compile('''
#       ~~~~^^^^^^^^^^^^
#       # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ...<32 lines>...
#       exec(compile(setup_py_code, filename, "exec"))
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ''' % ('C:\\Users\\princ\\AppData\\Local\\Temp\\pip-install-_hvz6zex\\htmlmin_82352119af2342b8b049641c0c04d331\\setup.py',), "<pip-setuptools-caller>", "exec"))
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "<pip-setuptools-caller>", line 35, in <module>
#     File "C:\Users\princ\AppData\Local\Temp\pip-install-_hvz6zex\htmlmin_82352119af2342b8b049641c0c04d331\setup.py", line 4, in <module>
#       from htmlmin import __version__
#     File "C:\Users\princ\AppData\Local\Temp\pip-install-_hvz6zex\htmlmin_82352119af2342b8b049641c0c04d331\htmlmin\__init__.py", line 28, in <module>
#       from .main import minify, Minifier
#     File "C:\Users\princ\AppData\Local\Temp\pip-install-_hvz6zex\htmlmin_82352119af2342b8b049641c0c04d331\htmlmin\main.py", line 28, in <module>
#       import cgi
#   ModuleNotFoundError: No module named 'cgi'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip uninstall pandas-profiling -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping pandas-profiling as it is not installed.

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\princ\anaconda3\lib\site-packages (4.18.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (2.10.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\princ\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\princ\anaconda3\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\princ\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\princ\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\princ\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\princ\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\princ\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\princ\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\princ\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\princ\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\princ\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\princ\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\princ\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\princ\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\princ\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\princ\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\princ\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\princ\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\princ\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\princ\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\princ\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\users\princ\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in c:\users\princ\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
from pandas_profiling import ProfileReport 
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.31it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
