# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Opening a local csv file

# %%
df = pd.read_csv('aug_test.zip')
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10:14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # Sep Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# # Index_col parameter

# %%
pd.read_csv('aug_test.zip',index_col = 'enrollee_id')
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 32403         city_41                   0.827    Male
# 9858         city_103                   0.920  Female
# 31806         city_21                   0.624    Male
# 27385         city_13                   0.827    Male
# 27724        city_103                   0.920    Male
# ...               ...                     ...     ...
# 1289         city_103                   0.920    Male
# 195          city_136                   0.897    Male
# 31762        city_100                   0.887    Male
# 7873         city_102                   0.804    Male
# 12215        city_102                   0.804    Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 32403        Has relevent experience    Full time course        Graduate
# 9858         Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Header Parameter

# %%
pd.read_csv('test.csv',header=1)

# %% [markdown]
# # use_cols parameter

# %%
pd.read_csv('aug_test.zip',usecols=['enrollee_id','gender'])
# Out:
#       enrollee_id  gender
# 0           32403    Male
# 1            9858  Female
# 2           31806    Male
# 3           27385    Male
# 4           27724    Male
# ...           ...     ...
# 2124         1289    Male
# 2125          195    Male
# 2126        31762    Male
# 2127         7873    Male
# 2128        12215    Male
#
# [2129 rows x 2 columns]

# %% [markdown]
# # Squeeze Parameters

# %%
enrollee_id = pd.read_csv('aug_test.zip', usecols=['enrollee_id']).squeeze()
enrollee_id
# Out:
# 0       32403
# 1        9858
# 2       31806
# 3       27385
# 4       27724
#         ...
# 2124     1289
# 2125      195
# 2126    31762
# 2127     7873
# 2128    12215
# Name: enrollee_id, Length: 2129, dtype: int64

# %% [markdown]
# # Skiprows/nrows Parameter

# %%
pd.read_csv('aug_test.zip',skiprows=[0,1])
pd.read_csv('aug_test.zip',nrows=100)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0         32403   city_41                   0.827    Male
# 1          9858  city_103                   0.920  Female
# 2         31806   city_21                   0.624    Male
# 3         27385   city_13                   0.827    Male
# 4         27724  city_103                   0.920    Male
# ..          ...       ...                     ...     ...
# 95         2934   city_75                   0.939    Male
# 96        12919  city_103                   0.920  Female
# 97         4386   city_21                   0.624    Male
# 98        22462   city_21                   0.624     NaN
# 99        13988  city_103                   0.920     NaN
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience    Full time course        Graduate
# 1   Has relevent experience       no_enrollment        Graduate
# 2    No relevent experience       no_enrollment     High School
# ...

# %% [markdown]
# # Encoding Parameter

# %%
pd.read_csv('aug_test.zip',encoding='latin-1')
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # skip bad lines

# %%
pd.read_csv('aug_test.zip', sep=';', encoding="latin-1",on_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pd.read_csv('aug_test.zip', sep=';', encoding="latin-1",on_bad_lines=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1013, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1010 del kwds["filepath_or_buffer"]
# ...

# %% [markdown]
# # dtypes Parameters

# %%
pd.read_csv('aug_test.zip').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.4+ KB

# %%
pd.read_csv('aug_test.zip',dtype={'target':int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.4+ KB

# %% [markdown]
# # Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('aug_test.zip',chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
